# %% [markdown]
# ## Dictionaries

# %%
## creation of an empty dictionary
empty_dict ={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
#also can be done by
empty_dict= dict()
empty_dict
# Out:
# {}

# %%
student = {"Name" : "Anas", "Age":19,"Grade":9.40}
print(student)
# Out:
# {'Name': 'Anas', 'Age': 19, 'Grade': 9.4}

# %%
## Single key is always used (last occurence is overritten for the key value pair for the same key given)
my_student={"name":"Anas","name": 21}
my_student
# Out:
# {'name': 21}

# %%
## Accesing Dictionary Elements dict['key']
print(student['Name'])
print(student['Age'])

## Using get() method
# Out:
# Anas
# 19

# %%
## Using the get() method
print(student.get('Name'))
print(student.get('Age'))
print(student.get('Grade'))

## for keys not present in the dict
print(student.get('Last_Name'))
print(student.get('Last_Name',"Not Found Key"))
# Out:
# Anas
# 19
# 9.4
# None
# Not Found Key

# %%
## Modifying The Dictionary
print(student)
# Out:
# {'Name': 'Anas', 'Age': 19, 'Grade': 9.4}

# %%
student["Age"]= 33
print(student)
student["Address"]= "Nagpur"
print(student)
# Out:
# {'Name': 'Anas', 'Age': 33, 'Grade': 9.4}
# {'Name': 'Anas', 'Age': 33, 'Grade': 9.4, 'Address': 'Nagpur'}

# %%
del student["Grade"]
print(student)
# Out:
# {'Name': 'Anas', 'Age': 33, 'Address': 'Nagpur'}

# %%
## Dictionary Methods

keys = student.keys()
print(keys)
values= student.values()
print(values)
items = student.items()
print(items)
# Out:
# dict_keys(['Name', 'Age', 'Address'])
# dict_values(['Anas', 33, 'Nagpur'])
# dict_items([('Name', 'Anas'), ('Age', 33), ('Address', 'Nagpur')])

# %%
## Shallow Copy
student_copy = student
print(student)
print(student_copy)
# Out:
# {'Name': 'Anas', 'Age': 33, 'Address': 'Nagpur'}
# {'Name': 'Anas', 'Age': 33, 'Address': 'Nagpur'}

# %%
student["Name"] = "Anas 2"
print(student)
print(student_copy)
# Out:
# {'Name': 'Anas 2', 'Age': 33, 'Address': 'Nagpur'}
# {'Name': 'Anas 2', 'Age': 33, 'Address': 'Nagpur'}

# %%
student_copy1=student.copy() ## shallow copy
print(student)
print(student_copy1)

student["Name"]="Anas 3"
print(student)
print(student_copy1)
# Out:
# {'Name': 'Anas 2', 'Age': 33, 'Address': 'Nagpur'}
# {'Name': 'Anas 2', 'Age': 33, 'Address': 'Nagpur'}
# {'Name': 'Anas 3', 'Age': 33, 'Address': 'Nagpur'}
# {'Name': 'Anas 2', 'Age': 33, 'Address': 'Nagpur'}

# %%
## Iterating over Dictionaries
student={"Name": "Anas","Age":19,"Address":"Nagpur"}
for keys in student.keys():
    print(keys)
# Out:
# Name
# Age
# Address

# %%
## iterate over values 
for values in student.values():
    print(values)
# Out:
# Anas
# 19
# Nagpur

# %%
## Iterate Over Key Value pairs
for key,value in student.items():
    print(f"{key} : {value}")
# Out:
# Name : Anas
# Age : 19
# Address : Nagpur

# %%
## Nested Dictionaries
students= {
    "student1":{"Name":"Anas","Age":19},
    "student2":{"Name":"Hamdan","Age":15}
}
print(students["student1"]["Name"])
print(students["student2"]["Name"])
print(students["student2"]["Age"])
# Out:
# Anas
# Hamdan
# 15

# %%
students.items()
# Out:
# dict_items([('student1', {'Name': 'Anas', 'Age': 19}), ('student2', {'Name': 'Hamdan', 'Age': 15})])

# %%
## Iterating Over nested Dictionaries
for student_id,student_info in students.items():
    print(f"{student_id} : {student_info}")
    for keys,values in student_info.items():
        print(f"{keys} : {values}")
    print()
# Out:
# student1 : {'Name': 'Anas', 'Age': 19}
# Name : Anas
# Age : 19
#
# student2 : {'Name': 'Hamdan', 'Age': 15}
# Name : Hamdan
# Age : 15

# %%
## Dictionary Comprehension
squares = {x:x**2 for x in range(1,5)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Conditional Dictionary Comprehension
evens ={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical Examples

## use a dict to count the frequency of elements in list
numbers=[1,2,2,3,3,3,4,4,4,4]
frequency = {}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
  
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge two Dictionaries into One
dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merge_dict={**dict1,**dict2}
print(merge_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
