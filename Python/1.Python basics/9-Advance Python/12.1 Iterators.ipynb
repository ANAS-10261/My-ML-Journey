# %% [markdown]
# **Iterators**
#
# An iterator is an object that contains a countable number of values. It is an object that can be iterated upon, meaning that you can traverse through all the values. In Python, an iterator is an object which implements the iterator protocol, which consist of the methods `__iter__()` and `__next__()`.

# %% [markdown]
# Iterators are advanced Python con€epts that allow for efficient looping and memory management. Iterators
# provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
iterator= iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 next(iterator)
#
# StopIteration:

# %%
iterator =iter (my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There are no elements in the iterator")
# Out:
# There are no elements in the iterator
